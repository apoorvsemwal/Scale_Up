# %%
print(2+1)
print("Hello")
# Out:
# 3
# Hello

# %%
2**16
# Out:
# 65536

# %%
a = [1,2,'Hello',True]

# %%
print(a[3])
# Out:
# True

# %%
a = a[0:2]

# %%
print(a)
# Out:
# [1, 2]

# %%
b = 'Hello'
b[::-1]
# Out:
# 'olleH'

# %%
c = [1,2,3,4,5,6]
c[0:4][::-1]
# Out:
# [4, 3, 2, 1]

# %%
c[3::-1]
# Out:
# [4, 3, 2, 1]

# %%
s = "abcd"
e = "xywz"
output = ""
input = 'batc'
for char in input:
    idx = s.find(char)
    if idx != -1:
        output = my_sum(output,e[idx])
        #output = output + e[idx]
    else:    
        print("Not Present")
print (output)
# Out:
# Not Present
# yxw

# %%
def my_sum(s1,s2):
    return s1+s2

# %%
d = {'a':1, 'marks':[1,2,3,4], True:-20}
print(d)
# Out:
# {'a': 1, 'marks': [1, 2, 3, 4], True: -20}

# %%
for item in d:
    print (d[item])
# Out:
# 1
# [1, 2, 3, 4]
# -20

# %%
import pandas as pd

# %%
data_frame = pd.DataFrame({'a':[1,2], 'b':[3,4]})

# %%
len(data_frame)
# Out:
# 2

# %%
data_frame = pd.read_csv("physician_rx.csv")

# %%
data_frame.head()
# Out:
#    PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 0  AP1912920        0.0           50            510        152           0
# 1  AP1350415     2370.0         1320             60       1416        2676
# 2  AP0129322        0.0           85              0          0         144
# 3  AP0462902       30.0          570              0        128        3900
# 4  AP3185026        0.0           40           1080          0           0

# %%
data_frame.tail() #Just to know our data how it looks like
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 95  AP1957774      390.0           15              0         16          36
# 96  AP1273998      480.0          630              0          0           0
# 97  AP1228990        0.0            0              0          0         180
# 98  AP1881803        0.0           10              0          0           0
# 99  AP4772804       10.0            0              0          0           0

# %%
data_frame.shape  #Shape of data frame
# Out:
# (100, 6)

# %%
data_frame.columns
# Out:
# Index(['PHYSICIAN', 'CroMax_RX', 'GlycoMax_RX', 'AllergyMax_RX', 'FevMax_RX',
#        'ColdMax_RX'],
#       dtype='object')

# %%
data_frame.dtypes #Type of each Coloumn - String is treated as Object
# Out:
# PHYSICIAN         object
# CroMax_RX        float64
# GlycoMax_RX        int64
# AllergyMax_RX      int64
# FevMax_RX          int64
# ColdMax_RX         int64
# dtype: object

# %%
data_frame[["PHYSICIAN","AllergyMax_RX"]][0:4] #Two brackets as it takes only one parameter so we club columns and put them in a list
#slower
# Out:
#    PHYSICIAN  AllergyMax_RX
# 0  AP1912920            510
# 1  AP1350415             60
# 2  AP0129322              0
# 3  AP0462902              0

# %%
data_frame.loc[0:4,"PHYSICIAN":"AllergyMax_RX"] #loc is in-built function to do sub-setting - we deal with labels here therefore last index is inclusive. 0-4 traeted as lablel 0-4.
# Out:
#    PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX
# 0  AP1912920        0.0           50            510
# 1  AP1350415     2370.0         1320             60
# 2  AP0129322        0.0           85              0
# 3  AP0462902       30.0          570              0
# 4  AP3185026        0.0           40           1080

# %%
data_frame.iloc[0:4,0:3] #iloc is in-built function to do sub-setting - we deal with indexe here therefore last index is excluded
# Out:
#    PHYSICIAN  CroMax_RX  GlycoMax_RX
# 0  AP1912920        0.0           50
# 1  AP1350415     2370.0         1320
# 2  AP0129322        0.0           85
# 3  AP0462902       30.0          570

# %%
data_frame.loc[0:4,["PHYSICIAN","AllergyMax_RX"]] #loc is in-built function to do sub-setting - we deal with labels here therefore last index is inclusive
# Out:
#    PHYSICIAN  AllergyMax_RX
# 0  AP1912920            510
# 1  AP1350415             60
# 2  AP0129322              0
# 3  AP0462902              0
# 4  AP3185026           1080

# %%
data_frame.iloc[0:4,[0,3]] #iloc is in-built function to do sub-setting - we deal with indexe here therefore last index is excluded
# iloc to be used if col sequencing is followed
# Out:
#    PHYSICIAN  AllergyMax_RX
# 0  AP1912920            510
# 1  AP1350415             60
# 2  AP0129322              0
# 3  AP0462902              0

# %%
data_frame[data_frame["CroMax_RX"] > 50]
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 1   AP1350415     2370.0         1320             60       1416        2676
# 5   AP3674571       70.0           40              0         64           0
# 7         NaN      150.0          315            270        184          36
# 10  AP1934892      640.0          390              0        280           0
# 11  AP1595288      160.0           35             45          0           0
# 13  AP1365782      400.0           15            255        704         444
# 14        NaN       90.0          150              0          0         204
# 16  AP0036951      330.0          525              0          0           0
# 21  AP1332969       90.0          870              0         88          24
# 22  AP2130355      160.0          145              0          0         180
# 23  AP0714887      160.0          780            615         16        2964
# ...

# %%
data_frame[(data_frame["CroMax_RX"] > 50) & (data_frame["GlycoMax_RX"] > 50)]
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 1   AP1350415     2370.0         1320             60       1416        2676
# 7         NaN      150.0          315            270        184          36
# 10  AP1934892      640.0          390              0        280           0
# 14        NaN       90.0          150              0          0         204
# 16  AP0036951      330.0          525              0          0           0
# 21  AP1332969       90.0          870              0         88          24
# 22  AP2130355      160.0          145              0          0         180
# 23  AP0714887      160.0          780            615         16        2964
# 26        NaN      150.0          220            510         32        1128
# 29  AP0089696      930.0          250           3435          0         396
# 31  AP0692473       90.0          215            375          0         348
# ...

# %%
len(data_frame[(data_frame["CroMax_RX"] > 50) | (data_frame["GlycoMax_RX"] > 50)]["PHYSICIAN"])
# Out:
# 76

# %%
data_frame[(data_frame["CroMax_RX"] > 50) & (data_frame["GlycoMax_RX"] > 50)]["PHYSICIAN"]
# Out:
# 1     AP1350415
# 7           NaN
# 10    AP1934892
# 14          NaN
# 16    AP0036951
# 21    AP1332969
# 22    AP2130355
# 23    AP0714887
# 26          NaN
# 29    AP0089696
# 31    AP0692473
# 40    AP0438309
# 42    AP1326350
# 53    AP1976314
# 55    AP3632706
# 56    AP1871832
# 57    AP0092627
# 59    AP1815618
# 64    AP0093884
# 67    AP0476079
# 68    AP1822470
# 71    AP0118925
# 74    AP1869077
# 76    AP1230067
# 79    AP1336198
# 82    AP1834639
# 85    AP0478796
# 87    AP2459335
# 89    AP0433841
# 96    AP1273998
# Name: PHYSICIAN, dtype: object

# %%
data_frame.iloc[0:1,0:1]
# Out:
#    PHYSICIAN
# 0  AP1912920

# %%
data_frame.iloc[0,0]
# Out:
# 'AP1912920'

# %%
data_frame.iat[0,0] #designed to give only one cell value unlike loc and iloc - Fastest - works with index
# Out:
# 'AP1912920'

# %%
data_frame.at[0,"PHYSICIAN"] #designed to give only one cell value unlike loc and iloc - Fastest - works with labels
# Out:
# 'AP1912920'

# %%
data_frame.isnull().sum()
# Out:
# PHYSICIAN        4
# CroMax_RX        4
# GlycoMax_RX      0
# AllergyMax_RX    0
# FevMax_RX        0
# ColdMax_RX       0
# dtype: int64

# %%
data_frame.isnull()
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 0       False      False        False          False      False       False
# 1       False      False        False          False      False       False
# 2       False      False        False          False      False       False
# 3       False      False        False          False      False       False
# 4       False      False        False          False      False       False
# 5       False      False        False          False      False       False
# 6       False      False        False          False      False       False
# 7        True      False        False          False      False       False
# 8       False      False        False          False      False       False
# 9       False      False        False          False      False       False
# 10      False      False        False          False      False       False
# ...

# %%
data_frame[data_frame["CroMax_RX"].isnull()]
# Out:
#     PHYSICIAN  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 33  AP0464297        NaN          405              0          0          36
# 48  AP1948690        NaN          105            690          8           0
# 65  AP2102094        NaN          220              0        432         216
# 88  AP0812453        NaN           45              0          0         264

# %%
data_frame["CroMax_RX"] = data_frame["CroMax_RX"].fillna(0) # Fill all nulls with zeros

# %%
data_frame["CroMax_RX"].isnull().sum()
# Out:
# 0

# %%
data_frame = data_frame.dropna()

# %%
data_frame.isnull().sum()
# Out:
# PHYSICIAN        0
# CroMax_RX        0
# GlycoMax_RX      0
# AllergyMax_RX    0
# FevMax_RX        0
# ColdMax_RX       0
# dtype: int64

# %%
data_frame.columns
# Out:
# Index(['PHYSICIAN', 'CroMax_RX', 'GlycoMax_RX', 'AllergyMax_RX', 'FevMax_RX',
#        'ColdMax_RX'],
#       dtype='object')

# %%
data_frame.rename(columns={'PHYSICIAN':'Phy'}) #Drawback is we ultimately have to type all col names.
# Out:
#           Phy  CroMax_RX  GlycoMax_RX  AllergyMax_RX  FevMax_RX  ColdMax_RX
# 0   AP1912920        0.0           50            510        152           0
# 1   AP1350415     2370.0         1320             60       1416        2676
# 2   AP0129322        0.0           85              0          0         144
# 3   AP0462902       30.0          570              0        128        3900
# 4   AP3185026        0.0           40           1080          0           0
# 5   AP3674571       70.0           40              0         64           0
# 6   AP0126982        0.0          135              0          0           0
# 8   AP1807651        0.0          650              0          0         300
# 9   AP0728371        0.0            0              0          0           0
# 10  AP1934892      640.0          390              0        280           0
# 11  AP1595288      160.0           35             45          0           0
# ...

# %%
"hello world".replace("l","z")
# Out:
# 'hezzo worzd'

# %%
data_frame.columns = data_frame.columns.str.replace("_",".") #str is an extension to use string functions in Pandas (Porting pandas o/p to string).

# %%
data_frame["PHYSICIAN"] = data_frame["PHYSICIAN"].str.replace("AP","AB")

# %%
data_frame["Bucket"] = "B2"

# %%
data_frame[(data_frame["CroMax.RX"]>50) & (data_frame["GlycoMax.RX"]>50)]["Bucket"] = "B1" #even though it does the change but chained subset creates a view and then does the change in it
# Out:
# F:\Concor\IDE\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_frame.loc[(data_frame["CroMax.RX"]>50) & (data_frame["GlycoMax.RX"]>50),"Bucket"] = "B1" #that is how its done safely

# %%
data_frame["New Phy"] = data_frame["Bucket"] + "_" + data_frame["PHYSICIAN"]

# %%
data_frame.head()
# Out:
#    PHYSICIAN  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX  \
# 0  AB1912920        0.0           50            510        152           0
# 1  AB1350415     2370.0         1320             60       1416        2676
# 2  AB0129322        0.0           85              0          0         144
# 3  AB0462902       30.0          570              0        128        3900
# 4  AB3185026        0.0           40           1080          0           0
#
#   Bucket bucket       New Phy
# 0     B2    NaN  B2_AB1912920
# 1     B2     B1  B2_AB1350415
# 2     B2    NaN  B2_AB0129322
# 3     B2    NaN  B2_AB0462902
# 4     B2    NaN  B2_AB3185026

# %%
data_frame.columns
# Out:
# Index(['PHYSICIAN', 'CroMax.RX', 'GlycoMax.RX', 'AllergyMax.RX', 'FevMax.RX',
#        'ColdMax.RX', 'Bucket', 'bucket', 'New Phy'],
#       dtype='object')

# %%
data_frame = data_frame[['New Phy', 'CroMax.RX', 'GlycoMax.RX', 'AllergyMax.RX', 'FevMax.RX',
       'ColdMax.RX', 'Bucket', 'bucket']] #Rearrannge or delete columns

# %%
data_frame.head()
# Out:
#         New Phy  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX  \
# 0  B2_AB1912920        0.0           50            510        152           0
# 1  B2_AB1350415     2370.0         1320             60       1416        2676
# 2  B2_AB0129322        0.0           85              0          0         144
# 3  B2_AB0462902       30.0          570              0        128        3900
# 4  B2_AB3185026        0.0           40           1080          0           0
#
#   Bucket bucket
# 0     B2    NaN
# 1     B2     B1
# 2     B2    NaN
# 3     B2    NaN
# 4     B2    NaN

# %%
data_frame["Physician"] = data_frame["New Phy"].str.split("_").str[1]
data_frame["New Bucket"] = data_frame["New Phy"].str.split("_").str[0]
# Out:
# F:\Concor\IDE\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# F:\Concor\IDE\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_frame.head()
# Out:
#         New Phy  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX  \
# 0  B2_AB1912920        0.0           50            510        152           0
# 1  B2_AB1350415     2370.0         1320             60       1416        2676
# 2  B2_AB0129322        0.0           85              0          0         144
# 3  B2_AB0462902       30.0          570              0        128        3900
# 4  B2_AB3185026        0.0           40           1080          0           0
#
#    Physician New Bucket
# 0  AB1912920         B2
# 1  AB1350415         B2
# 2  AB0129322         B2
# 3  AB0462902         B2
# 4  AB3185026         B2

# %%
data_frame.columns
# Out:
# Index(['New Phy', 'CroMax.RX', 'GlycoMax.RX', 'AllergyMax.RX', 'FevMax.RX',
#        'ColdMax.RX', 'Physician', 'New Bucket'],
#       dtype='object')

# %%
data_frame = data_frame[['New Phy', 'CroMax.RX', 'GlycoMax.RX', 'AllergyMax.RX', 'FevMax.RX',
       'ColdMax.RX', 'Physician', 'New Bucket']]

# %%
data_frame.head()
# Out:
#         New Phy  CroMax.RX  GlycoMax.RX  AllergyMax.RX  FevMax.RX  ColdMax.RX  \
# 0  B2_AB1912920        0.0           50            510        152           0
# 1  B2_AB1350415     2370.0         1320             60       1416        2676
# 2  B2_AB0129322        0.0           85              0          0         144
# 3  B2_AB0462902       30.0          570              0        128        3900
# 4  B2_AB3185026        0.0           40           1080          0           0
#
#    Physician New Bucket
# 0  AB1912920         B2
# 1  AB1350415         B2
# 2  AB0129322         B2
# 3  AB0462902         B2
# 4  AB3185026         B2

# %%
#data_frame = data_frame.iloc[:,1:] - To remove 1st coloumn
